# %%
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.0
#     Uninstalling click-8.3.0:
#       Successfully uninstalled click-8.3.0
# ...

# %%
# Описание желаемого стиля речи
desired_style = """
Романтический стиль речи характеризуется:
— Эмоциональной насыщенностью и лиризмом,
— Мягкой, плавной интонацией,
— Выразительными паузами и замедленным темпом в ключевых моментах,
— Акцентом на образах, чувствах и внутреннем переживании.

Цель: передать это настроение через синтезированную речь.
"""

# Обоснование выбора текста
text_choice_justification = """
Стихотворение А.С. Пушкина «Я помню чудное мгновенье…» выбрано потому, что:
— Это классический образец русской романтической лирики,
— Текст наполнен эмоциями восхищения, нежности и возвышенной любви,
— Язык поэтичен, образен и ритмичен — идеально отражает суть романтического стиля.
"""

print(" Желаемый стиль речи:")
print(desired_style)
print("\n📜 Обоснование выбора текста:")
print(text_choice_justification)
# Out:
# 🎯 Желаемый стиль речи:
#
# Романтический стиль речи характеризуется:
# — Эмоциональной насыщенностью и лиризмом,
# — Мягкой, плавной интонацией,
# — Выразительными паузами и замедленным темпом в ключевых моментах,
# — Акцентом на образах, чувствах и внутреннем переживании.
#
# Цель: передать это настроение через синтезированную речь.
#
#
# 📜 Обоснование выбора текста:
#
# Стихотворение А.С. Пушкина «Я помню чудное мгновенье…» выбрано потому, что:
# — Это классический образец русской романтической лирики,
# — Текст наполнен эмоциями восхищения, нежности и возвышенной любви,
# — Язык поэтичен, образен и ритмичен — идеально отражает суть романтического стиля.

# %%
from gtts import gTTS

# Сам текст стихотворения
text = """
Я помню чудное мгновенье:
Передо мной явилась ты,
Как мимолётное виденье,
Как гений чистой красоты.
"""

# Синтез на русском языке
tts = gTTS(text=text, lang='ru', slow=False)
tts.save("romantic_poem.mp3")

print(" Аудио сохранено как romantic_poem.mp3")
# Out:
# ✅ Аудио сохранено как romantic_poem.mp3

# %%
from IPython.display import Audio, display

# Воспроизведение
display(Audio("romantic_poem.mp3", autoplay=False))

# Выводы
conclusion = """
Оценка результата:

— Текст действительно передаёт романтический стиль на уровне содержания.
— Однако синтезированная речь (через gTTS) звучит нейтрально, без эмоциональной окраски,
  выразительных пауз, динамических изменений темпа или интонации.
— Следовательно, **романтический стиль речи не был реализован на акустическом уровне**.

 Вывод:
Задача **частично выполнена**: романтический стиль присутствует в тексте,
но не передан в синтезированной речи из-за ограничений gTTS.
Для полноценной передачи стиля необходимы TTS-системы с поддержкой
эмоциональной просодии (например, Coqui TTS, FastSpeech 2 с эмоциональным контролем,
или коммерческие решения вроде Amazon Polly с SSML-разметкой).
"""

print(conclusion)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 🔍 Оценка результата:
#
# — Текст действительно передаёт романтический стиль на уровне содержания.
# — Однако синтезированная речь (через gTTS) звучит нейтрально, без эмоциональной окраски,
#   выразительных пауз, динамических изменений темпа или интонации.
# — Следовательно, **романтический стиль речи не был реализован на акустическом уровне**.
#
# 💡 Вывод:
# Задача **частично выполнена**: романтический стиль присутствует в тексте,
# но не передан в синтезированной речи из-за ограничений gTTS.
# Для полноценной передачи стиля необходимы TTS-системы с поддержкой
# эмоциональной просодии (например, Coqui TTS, FastSpeech 2 с эмоциональным контролем,
# или коммерческие решения вроде Amazon Polly с SSML-разметкой).
